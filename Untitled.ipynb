# %% [markdown]
# # Anomaly detection

# %% [markdown]
# ## Preprocessing Data
# The first thing to be done is to create the training data from the csv files

# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import os

training_dir = "data_for_testing"
print('datasets -',len(os.listdir(training_dir)))

df = pd.read_csv("A1Benchmark/real_11.csv")
df['value'].plot(linewidth=0.3)
print(os.listdir(training_dir))
# Out:
# datasets - 1
# ['real_1.csv']

# %% [markdown]
# ### This is a class to create arrays of data

# %%
import numpy as np 
class preprocesser:
    
    #initialize the lists for the data and labels
    def __init__(self):
        self.data = []
        self.labels = []
        
    def add_data (self, dataset, window_size, sliding_size,anomalies):
        label_indexes = int(len(dataset)/(sliding_size))-window_size
        for i in range(label_indexes):
            if anomalies[i*sliding_size+window_size] == 0:
                #print(dataset[i*sliding_size : i*sliding_size+window_size])
                self.data.append(dataset[i*sliding_size : i*sliding_size+window_size])
                #print(dataset[i*sliding_size+window_size])
                self.labels.append(dataset[i*sliding_size+window_size])
        
    def return_data(self):
        return np.array(self.data), np.array(self.labels)

# %% [markdown]
# ### In here I create 2 arrays, one with the data and the other with the labels ( Which in this case is the next value)

# %%
#define window size we will work with
window_size = 20
preproc = preprocesser()

for d in os.listdir(training_dir):
    df = pd.read_csv('A1Benchmark/'+d)
    preproc.add_data(dataset=df['value'], window_size = window_size, sliding_size = 1, anomalies = df['is_anomaly'])
data, labels = preproc.return_data()

# %% [markdown]
# We have almost 100.000 datapoints

# %%
data.shape, labels.shape
# Out:
# ((1398, 20), (1398,))

# %%
data =data.reshape((1398, window_size,-1))
data.shape
# Out:
# (1398, 20, 1)

# %%
def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block as defined in Figure 3
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = tf.keras.layers.Conv1D(filters = F1, kernel_size = (1), strides = (1), padding = 'valid', name = conv_name_base + '2a')(X)
    X = tf.keras.layers.BatchNormalization(name = bn_name_base + '2a')(X)
    X = tf.keras.layers.Activation('relu')(X)

    
    # Second component of main path (≈3 lines)
    X = tf.keras.layers.Conv1D(filters = F2, kernel_size = (f), strides = (1), padding = 'same', name = conv_name_base + '2b')(X)
    X = tf.keras.layers.BatchNormalization(name = bn_name_base + '2b')(X)
    X = tf.keras.layers.Activation('relu')(X)

    # Third component of main path (≈2 lines)
    X = tf.keras.layers.Conv1D(filters = F3, kernel_size = (1), strides = (1), padding = 'valid', name = conv_name_base + '2c')(X)
    X = tf.keras.layers.BatchNormalization(name = bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = tf.keras.layers.Add()([X, X_shortcut])
    X = tf.keras.layers.Activation('relu')(X)
    
    
    return X

# %%
def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Implementation of the convolutional block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = tf.keras.layers.Conv1D(F1, (1), strides = (s), name = conv_name_base + '2a')(X)
    X = tf.keras.layers.BatchNormalization(name = bn_name_base + '2a')(X)
    X = tf.keras.layers.Activation('relu')(X)

    # Second component of main path (≈3 lines)
    X = tf.keras.layers.Conv1D(filters = F2, kernel_size = (f), strides = (1), padding = 'same', name = conv_name_base + '2b')(X)
    X = tf.keras.layers.BatchNormalization(name = bn_name_base + '2b')(X)
    X = tf.keras.layers.Activation('relu')(X)


    # Third component of main path (≈2 lines)
    X = tf.keras.layers.Conv1D(filters = F3, kernel_size = (1), strides = (1), padding = 'valid', name = conv_name_base + '2c')(X)
    X = tf.keras.layers.BatchNormalization(name = bn_name_base + '2c')(X)


    ##### SHORTCUT PATH #### (≈2 lines)
    X_shortcut = tf.keras.layers.Conv1D(filters = F3, kernel_size = (1), strides = (s), padding = 'valid', name = conv_name_base + '1')(X_shortcut)
    X_shortcut = tf.keras.layers.BatchNormalization(name = bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = tf.keras.layers.Add()([X, X_shortcut])
    X = tf.keras.layers.Activation('relu')(X)
    
    
    return X

# %%
def ResNet(input_shape=(20, 1), classes=1):
    
    # Define the input as a tensor with shape input_shape
    X_input = tf.keras.layers.Input(input_shape)
    
    X = convolutional_block(X_input, f=3, filters=[4, 4, 8], stage=2, block='a', s=1)
    X = identity_block(X, 3, [4, 4, 8], stage=2, block='b')
    X = identity_block(X, 3, [4, 4, 8], stage=2, block='c')
    
    X = convolutional_block(X, f=3, filters=[8, 8, 16], stage=3, block='a', s=1)
    X = identity_block(X, 3, [8, 8, 16], stage=3, block='b')
    X = identity_block(X, 3, [8, 8, 16], stage=3, block='c')
    

    X = tf.keras.layers.AveragePooling1D(2, name="avg_pool")(X)
    X = tf.keras.layers.Flatten()(X)
    X = tf.keras.layers.Dense(classes, activation='linear', name='fc' + str(classes))(X)
    
    model = tf.keras.models.Model(inputs = X_input, outputs = X, name='ResNet')

    return model

# %%
model = ResNet(input_shape = (window_size,1), classes = 1)

# %%
model.compile(optimizer=tf.keras.optimizers.RMSprop(), loss='mean_squared_error')

# %%
training = model.fit(data, labels, batch_size=32,epochs=50,verbose=1)
# Out:
# Train on 1398 samples
# Epoch 1/50
# 1398/1398 [==============================] - 1s 481us/sample - loss: 0.0045
# Epoch 2/50
# 1398/1398 [==============================] - 1s 472us/sample - loss: 0.0044
# Epoch 3/50
# 1398/1398 [==============================] - 1s 476us/sample - loss: 0.0038
# Epoch 4/50
# 1398/1398 [==============================] - 1s 482us/sample - loss: 0.0044
# Epoch 5/50
# 1398/1398 [==============================] - 1s 480us/sample - loss: 0.0042
# Epoch 6/50
# 1398/1398 [==============================] - 1s 488us/sample - loss: 0.0041
# Epoch 7/50
# 1398/1398 [==============================] - 1s 492us/sample - loss: 0.0040
# Epoch 8/50
# 1398/1398 [==============================] - 1s 474us/sample - loss: 0.0037
# Epoch 9/50
# 1398/1398 [==============================] - 1s 483us/sample - loss: 0.0038
# Epoch 10/50
# 1398/1398 [==============================] - 1s 478us/sample - loss: 0.0042
# Epoch 11/50
# 1398/1398 [==============================] - 1s 481us/sample - loss: 0.0044
# Epoch 12/50
# 1398/1398 [==============================] - 1s 481us/sample - loss: 0.0039
# Epoch 13/50
# 1398/1398 [==============================] - 1s 474us/sample - loss: 0.0037
# Epoch 14/50
# 1398/1398 [==============================] - 1s 481us/sample - loss: 0.0040
# Epoch 15/50
# 1398/1398 [==============================] - 1s 467us/sample - loss: 0.0036
# Epoch 16/50
# 1398/1398 [==============================] - 1s 477us/sample - loss: 0.0039
# Epoch 17/50
# 1398/1398 [==============================] - 1s 476us/sample - loss: 0.0033
# Epoch 18/50
# 1398/1398 [==============================] - 1s 486us/sample - loss: 0.0036
# Epoch 19/50
# 1398/1398 [==============================] - 1s 476us/sample - loss: 0.0036
# Epoch 20/50
# 1398/1398 [==============================] - 1s 472us/sample - loss: 0.0041
# Epoch 21/50
# 1398/1398 [==============================] - 1s 470us/sample - loss: 0.0038
# Epoch 22/50
# 1398/1398 [==============================] - 1s 477us/sample - loss: 0.0036
# Epoch 23/50
# 1398/1398 [==============================] - 1s 482us/sample - loss: 0.0039
# Epoch 24/50
# 1398/1398 [==============================] - 1s 475us/sample - loss: 0.0038
# Epoch 25/50
# 1398/1398 [==============================] - 1s 478us/sample - loss: 0.0039
# Epoch 26/50
# 1398/1398 [==============================] - 1s 481us/sample - loss: 0.0035
# Epoch 27/50
# 1398/1398 [==============================] - 1s 472us/sample - loss: 0.0039
# Epoch 28/50
# 1398/1398 [==============================] - 1s 470us/sample - loss: 0.0037
# Epoch 29/50
# 1398/1398 [==============================] - 1s 480us/sample - loss: 0.0033
# Epoch 30/50
# 1398/1398 [==============================] - 1s 471us/sample - loss: 0.0034
# Epoch 31/50
# 1398/1398 [==============================] - 1s 483us/sample - loss: 0.0035
# Epoch 32/50
# 1398/1398 [==============================] - 1s 481us/sample - loss: 0.0035
# Epoch 33/50
# 1398/1398 [==============================] - 1s 488us/sample - loss: 0.0034
# Epoch 34/50
# 1398/1398 [==============================] - 1s 463us/sample - loss: 0.0034
# Epoch 35/50
# 1398/1398 [==============================] - 1s 483us/sample - loss: 0.0038
# Epoch 36/50
# 1398/1398 [==============================] - 1s 476us/sample - loss: 0.0035
# Epoch 37/50
# 1398/1398 [==============================] - 1s 480us/sample - loss: 0.0035
# Epoch 38/50
# 1398/1398 [==============================] - 1s 477us/sample - loss: 0.0039
# Epoch 39/50
# 1398/1398 [==============================] - 1s 477us/sample - loss: 0.0034
# Epoch 40/50
# 1398/1398 [==============================] - 1s 473us/sample - loss: 0.0032
# Epoch 41/50
# 1398/1398 [==============================] - 1s 471us/sample - loss: 0.0038
# Epoch 42/50
# 1398/1398 [==============================] - 1s 488us/sample - loss: 0.0035
# Epoch 43/50
# 1398/1398 [==============================] - 1s 463us/sample - loss: 0.0035
# Epoch 44/50
# 1398/1398 [==============================] - 1s 463us/sample - loss: 0.0032
# Epoch 45/50
# 1398/1398 [==============================] - 1s 468us/sample - loss: 0.0032
# Epoch 46/50
# 1398/1398 [==============================] - 1s 471us/sample - loss: 0.0034
# Epoch 47/50
# 1398/1398 [==============================] - 1s 476us/sample - loss: 0.0033
# Epoch 48/50
# 1398/1398 [==============================] - 1s 471us/sample - loss: 0.0034
# Epoch 49/50
# 1398/1398 [==============================] - 1s 485us/sample - loss: 0.0033
# Epoch 50/50
# 1398/1398 [==============================] - 1s 483us/sample - loss: 0.0033

# %%
model.predict(data)
# Out:
# array([[0.08914628],
#        [0.08355599],
#        [0.06346906],
#        ...,
#        [0.13928664],
#        [0.13550341],
#        [0.08182614]], dtype=float32)

# %%
fig, ax = plt.subplots()
fig.set_size_inches(30.5, 20.5)
ax.plot(model.predict(data),linewidth=0.2, c='blue')
ax.plot(labels,linewidth=0.2, c='red')
